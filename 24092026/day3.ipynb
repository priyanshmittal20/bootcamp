# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:\\Users\\Harshit Sharma\\Downloads\\Vscode\\BootCamp\\Images.jpeg')
print(type(img))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img = cv2.imread('C:\\Users\\Harshit Sharma\\Downloads\\Vscode\\BootCamp\\Images.jpeg')
#       2 print(type(img))
#       3
#
# NameError: name 'cv2' is not defined

# %%
# printing the image shape and displaying the image
print(img.shape)
cv2.imshow("photos",img)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # printing the image shape and displaying the image
# ----> 2 print(img.shape)
#       3 cv2.imshow("photos",img)
#       4 cv2.waitKey(0)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# for resizing the image 
img_resize =cv2.resize(img,(450,256))
cv2.imshow("photos",img_resize)
cv2.waitKey(0)
# Out:
# -1

# %%
# flipping the image
img_flip = cv2.flip(img,0)
cv2.imshow("photos",img_flip)
cv2.waitKey(0)
# Out:
# -1

# %%
# for cropping the image
img_crop = img[100:300,200:500]
cv2.imshow("photos",img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # for cropping the image
# ----> 2 img_crop = img[100:300,200:500]
#       3 cv2.imshow("photos",img_crop)
#       4 cv2.waitKey(0)
#       5 cv2.destroyAllWindows()
#
# NameError: name 'img' is not defined
